# %% [markdown]
# #  프로젝트 : Segmentation map으로 도로 이미지 만들기
#
# 이전 포켓몬 데이터에서 사용했던 스케치와는 조금 다른 레이블 정보 이미지를 입력으로 사용하기 때문에, 전처리 과정에 대해 약간의 혼란이 있을 수 있지만 크게 다른 과정은 없습니다.
# 아래 Tensroflow에서 제공하는 Pix2Pix 튜토리얼은 위 이미지와 비슷한 레이블 정보 이미지를 사용하기 때문에 좋은 참고 자료가 될 수 있을 것 같습니다.
#
# 프로젝트를 수행하기 전에 주요 라이브러리 버전을 살펴 봅시다.

# %%
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %% [markdown]
# ### 프로젝트 수행
# 프로젝트를 진행하면서 필수로 수행해야 할 사항은 다음과 같습니다.
#
# - 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요.
# (어떠한 방법을 사용했는지 적어주세요.)
# - 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# - 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# - 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# - 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %% [markdown]
# ## Load Data

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/City/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %% [markdown]
# ## Visualizing

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %% [markdown]
# ## Image shape

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %% [markdown]
# ## normalize, denormalize, load_img functions

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# ## Apply Augmentation

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ## Making Generator
#
# Make Generator using Subclassing.

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_24 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_25 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_24[0][0]
# __________________________________________________________________________________________________
# encode_block_26 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_25[0][0]
# __________________________________________________________________________________________________
# encode_block_27 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_26[0][0]
# __________________________________________________________________________________________________
# encode_block_28 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_27[0][0]
# __________________________________________________________________________________________________
# encode_block_29 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_28[0][0]
# __________________________________________________________________________________________________
# encode_block_30 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_29[0][0]
# __________________________________________________________________________________________________
# encode_block_31 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_30[0][0]
# __________________________________________________________________________________________________
# decode_block_21 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_31[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 2, 2, 1024)   0           decode_block_21[0][0]
#                                                                  encode_block_30[0][0]
# __________________________________________________________________________________________________
# decode_block_22 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 4, 4, 1024)   0           decode_block_22[0][0]
#                                                                  encode_block_29[0][0]
# __________________________________________________________________________________________________
# decode_block_23 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 8, 8, 1024)   0           decode_block_23[0][0]
#                                                                  encode_block_28[0][0]
# __________________________________________________________________________________________________
# decode_block_24 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_27[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 16, 16, 1024) 0           decode_block_24[0][0]
#                                                                  encode_block_27[0][0]
# __________________________________________________________________________________________________
# decode_block_25 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 32, 32, 512)  0           decode_block_25[0][0]
#                                                                  encode_block_26[0][0]
# __________________________________________________________________________________________________
# decode_block_26 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_29[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 64, 64, 256)  0           decode_block_26[0][0]
#                                                                  encode_block_25[0][0]
# __________________________________________________________________________________________________
# decode_block_27 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_30[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 128, 128, 128 0           decode_block_27[0][0]
#                                                                  encode_block_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_31[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ## Making Discriminator

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 256, 256, 6)  0           input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# disc_block_20 (DiscBlock)       (None, 128, 128, 64) 6144        concatenate_32[0][0]
# __________________________________________________________________________________________________
# disc_block_21 (DiscBlock)       (None, 64, 64, 128)  131584      disc_block_20[0][0]
# __________________________________________________________________________________________________
# disc_block_22 (DiscBlock)       (None, 32, 32, 256)  525312      disc_block_21[0][0]
# __________________________________________________________________________________________________
# disc_block_23 (DiscBlock)       (None, 31, 31, 512)  2099200     disc_block_22[0][0]
# __________________________________________________________________________________________________
# disc_block_24 (DiscBlock)       (None, 30, 30, 1)    8192        disc_block_23[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 30, 30, 1)    0           disc_block_24[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# test working

# 시험삼아 (256,256,3) 크기 입력을 넣어 (30, 30)이 나오는지 확인
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ## Train and Test

# %%
#discriminator와 generator의 loss 계산하는 함수
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
# Optimizer

from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
# update train_step

@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 50

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 100회 반복마다 손실을 출력합니다.
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:1.8792
# L1_loss:0.2587
# Discriminator_loss:0.4616
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.4214
# L1_loss:0.1976
# Discriminator_loss:0.9195
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.8247
# L1_loss:0.1841
# Discriminator_loss:0.4680
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.8431
# L1_loss:0.2191
# Discriminator_loss:0.3710
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.4992
# L1_loss:0.2452
# Discriminator_loss:1.0747
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.2340
# L1_loss:0.2020
# Discriminator_loss:0.5765
#
# EPOCH[4] - STEP[100]
# Generator_loss:3.2889
# L1_loss:0.2230
# Discriminator_loss:0.6326
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6741
# L1_loss:0.1855
# Discriminator_loss:0.3791
#
# EPOCH[5] - STEP[100]
# Generator_loss:0.8871
# L1_loss:0.2104
# Discriminator_loss:0.8955
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.8545
# L1_loss:0.1946
# Discriminator_loss:0.4463
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.9194
# L1_loss:0.1990
# Discriminator_loss:1.1068
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.7681
# L1_loss:0.1917
# Discriminator_loss:1.9573
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.7737
# L1_loss:0.1442
# Discriminator_loss:0.9045
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.2901
# L1_loss:0.1927
# Discriminator_loss:0.9000
#
# EPOCH[8] - STEP[100]
# Generator_loss:3.0155
# L1_loss:0.1950
# Discriminator_loss:0.8089
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.5520
# L1_loss:0.1746
# Discriminator_loss:0.4892
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.2615
# L1_loss:0.2153
# Discriminator_loss:0.2397
#
# EPOCH[9] - STEP[200]
# Generator_loss:2.1041
# L1_loss:0.1950
# Discriminator_loss:0.2334
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.0517
# L1_loss:0.1359
# Discriminator_loss:0.9150
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.1573
# L1_loss:0.1551
# Discriminator_loss:0.4650
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.3447
# L1_loss:0.1920
# Discriminator_loss:0.3603
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.0523
# L1_loss:0.1762
# Discriminator_loss:0.7590
#
# EPOCH[12] - STEP[100]
# Generator_loss:0.6344
# L1_loss:0.1749
# Discriminator_loss:1.0882
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.1771
# L1_loss:0.1459
# Discriminator_loss:0.7544
#
# EPOCH[13] - STEP[100]
# Generator_loss:1.1366
# L1_loss:0.1998
# Discriminator_loss:0.6256
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.1971
# L1_loss:0.1979
# Discriminator_loss:1.0070
#
# EPOCH[14] - STEP[100]
# Generator_loss:2.2657
# L1_loss:0.1790
# Discriminator_loss:0.4186
#
# EPOCH[14] - STEP[200]
# Generator_loss:2.2691
# L1_loss:0.1621
# Discriminator_loss:1.0688
#
# EPOCH[15] - STEP[100]
# Generator_loss:1.0742
# L1_loss:0.1857
# Discriminator_loss:0.6301
#
# EPOCH[15] - STEP[200]
# Generator_loss:0.6004
# L1_loss:0.1864
# Discriminator_loss:1.0636
#
# EPOCH[16] - STEP[100]
# Generator_loss:2.4241
# L1_loss:0.1698
# Discriminator_loss:0.2824
#
# EPOCH[16] - STEP[200]
# Generator_loss:3.0141
# L1_loss:0.1467
# Discriminator_loss:0.4436
#
# EPOCH[17] - STEP[100]
# Generator_loss:2.7999
# L1_loss:0.1404
# Discriminator_loss:1.0349
#
# EPOCH[17] - STEP[200]
# Generator_loss:1.0806
# L1_loss:0.1719
# Discriminator_loss:0.7375
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.6257
# L1_loss:0.1647
# Discriminator_loss:0.3982
#
# EPOCH[18] - STEP[200]
# Generator_loss:2.2089
# L1_loss:0.1341
# Discriminator_loss:0.4363
#
# EPOCH[19] - STEP[100]
# Generator_loss:0.8266
# L1_loss:0.1638
# Discriminator_loss:0.7969
#
# EPOCH[19] - STEP[200]
# Generator_loss:0.7911
# L1_loss:0.1878
# Discriminator_loss:1.1611
#
# EPOCH[20] - STEP[100]
# Generator_loss:2.7640
# L1_loss:0.1947
# Discriminator_loss:0.5729
#
# EPOCH[20] - STEP[200]
# Generator_loss:0.9116
# L1_loss:0.1510
# Discriminator_loss:1.4573
#
# EPOCH[21] - STEP[100]
# Generator_loss:2.8419
# L1_loss:0.1747
# Discriminator_loss:0.5979
#
# EPOCH[21] - STEP[200]
# Generator_loss:1.2545
# L1_loss:0.1885
# Discriminator_loss:0.4866
#
# EPOCH[22] - STEP[100]
# Generator_loss:1.0176
# L1_loss:0.2079
# Discriminator_loss:0.7062
#
# EPOCH[22] - STEP[200]
# Generator_loss:2.3650
# L1_loss:0.1448
# Discriminator_loss:0.9081
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.0744
# L1_loss:0.1442
# Discriminator_loss:0.7513
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.7409
# L1_loss:0.1824
# Discriminator_loss:0.4826
#
# EPOCH[24] - STEP[100]
# Generator_loss:2.8766
# L1_loss:0.1857
# Discriminator_loss:0.1602
#
# EPOCH[24] - STEP[200]
# Generator_loss:1.8047
# L1_loss:0.1803
# Discriminator_loss:0.3866
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.2197
# L1_loss:0.1337
# Discriminator_loss:0.5133
#
# EPOCH[25] - STEP[200]
# Generator_loss:0.7986
# L1_loss:0.1443
# Discriminator_loss:1.3344
#
# EPOCH[26] - STEP[100]
# Generator_loss:2.6598
# L1_loss:0.1494
# Discriminator_loss:0.4686
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.9799
# L1_loss:0.1399
# Discriminator_loss:1.1798
#
# EPOCH[27] - STEP[100]
# Generator_loss:3.8362
# L1_loss:0.1524
# Discriminator_loss:0.2586
#
# EPOCH[27] - STEP[200]
# Generator_loss:4.4093
# L1_loss:0.1519
# Discriminator_loss:1.5461
#
# EPOCH[28] - STEP[100]
# Generator_loss:0.7725
# L1_loss:0.1828
# Discriminator_loss:0.9291
#
# EPOCH[28] - STEP[200]
# Generator_loss:1.3637
# L1_loss:0.1566
# Discriminator_loss:0.5733
#
# EPOCH[29] - STEP[100]
# Generator_loss:2.0815
# L1_loss:0.1826
# Discriminator_loss:0.3009
#
# EPOCH[29] - STEP[200]
# Generator_loss:2.4887
# L1_loss:0.1354
# Discriminator_loss:0.4148
#
# EPOCH[30] - STEP[100]
# Generator_loss:6.2703
# L1_loss:0.1719
# Discriminator_loss:0.3793
#
# EPOCH[30] - STEP[200]
# Generator_loss:2.2475
# L1_loss:0.1385
# Discriminator_loss:0.5788
#
# EPOCH[31] - STEP[100]
# Generator_loss:3.0234
# L1_loss:0.1296
# Discriminator_loss:0.6478
#
# EPOCH[31] - STEP[200]
# Generator_loss:2.9170
# L1_loss:0.1457
# Discriminator_loss:0.2366
#
# EPOCH[32] - STEP[100]
# Generator_loss:1.3923
# L1_loss:0.1443
# Discriminator_loss:0.5522
#
# EPOCH[32] - STEP[200]
# Generator_loss:3.5879
# L1_loss:0.1997
# Discriminator_loss:0.1557
#
# EPOCH[33] - STEP[100]
# Generator_loss:1.2918
# L1_loss:0.1893
# Discriminator_loss:0.6211
#
# EPOCH[33] - STEP[200]
# Generator_loss:3.0412
# L1_loss:0.1635
# Discriminator_loss:0.1869
#
# EPOCH[34] - STEP[100]
# Generator_loss:2.6820
# L1_loss:0.1371
# Discriminator_loss:0.8010
#
# EPOCH[34] - STEP[200]
# Generator_loss:2.1721
# L1_loss:0.2025
# Discriminator_loss:0.4022
#
# EPOCH[35] - STEP[100]
# Generator_loss:2.4642
# L1_loss:0.1535
# Discriminator_loss:0.3962
#
# EPOCH[35] - STEP[200]
# Generator_loss:4.4764
# L1_loss:0.1799
# Discriminator_loss:0.5090
#
# EPOCH[36] - STEP[100]
# Generator_loss:3.5555
# L1_loss:0.1787
# Discriminator_loss:0.1430
#
# EPOCH[36] - STEP[200]
# Generator_loss:2.2005
# L1_loss:0.1306
# Discriminator_loss:0.3882
#
# EPOCH[37] - STEP[100]
# Generator_loss:1.3312
# L1_loss:0.1511
# Discriminator_loss:0.6791
#
# EPOCH[37] - STEP[200]
# Generator_loss:2.6511
# L1_loss:0.1787
# Discriminator_loss:0.1477
#
# EPOCH[38] - STEP[100]
# Generator_loss:2.0261
# L1_loss:0.1399
# Discriminator_loss:0.4167
#
# EPOCH[38] - STEP[200]
# Generator_loss:1.7636
# L1_loss:0.1216
# Discriminator_loss:0.5935
#
# EPOCH[39] - STEP[100]
# Generator_loss:0.7284
# L1_loss:0.1519
# Discriminator_loss:0.9472
#
# EPOCH[39] - STEP[200]
# Generator_loss:2.7357
# L1_loss:0.1601
# Discriminator_loss:0.1891
#
# EPOCH[40] - STEP[100]
# Generator_loss:1.1257
# L1_loss:0.1547
# Discriminator_loss:0.6532
#
# EPOCH[40] - STEP[200]
# Generator_loss:0.6476
# L1_loss:0.1716
# Discriminator_loss:1.0931
#
# EPOCH[41] - STEP[100]
# Generator_loss:3.0863
# L1_loss:0.1411
# Discriminator_loss:0.1915
#
# EPOCH[41] - STEP[200]
# Generator_loss:2.8324
# L1_loss:0.1321
# Discriminator_loss:0.1690
#
# EPOCH[42] - STEP[100]
# Generator_loss:2.0407
# L1_loss:0.1642
# Discriminator_loss:0.2303
#
# EPOCH[42] - STEP[200]
# Generator_loss:4.1655
# L1_loss:0.1453
# Discriminator_loss:0.1066
#
# EPOCH[43] - STEP[100]
# Generator_loss:1.6585
# L1_loss:0.1144
# Discriminator_loss:0.5087
#
# EPOCH[43] - STEP[200]
# Generator_loss:1.0619
# L1_loss:0.1266
# Discriminator_loss:0.8456
#
# EPOCH[44] - STEP[100]
# Generator_loss:2.2991
# L1_loss:0.1432
# Discriminator_loss:0.3914
#
# EPOCH[44] - STEP[200]
# Generator_loss:1.8603
# L1_loss:0.1552
# Discriminator_loss:0.3303
#
# EPOCH[45] - STEP[100]
# Generator_loss:3.3906
# L1_loss:0.1607
# Discriminator_loss:0.1712
#
# EPOCH[45] - STEP[200]
# Generator_loss:3.7253
# L1_loss:0.1556
# Discriminator_loss:0.0789
#
# EPOCH[46] - STEP[100]
# Generator_loss:3.3888
# L1_loss:0.1337
# Discriminator_loss:0.2968
#
# EPOCH[46] - STEP[200]
# Generator_loss:2.9643
# L1_loss:0.1425
# Discriminator_loss:0.2418
#
# EPOCH[47] - STEP[100]
# Generator_loss:2.9497
# L1_loss:0.1335
# Discriminator_loss:0.1641
#
# EPOCH[47] - STEP[200]
# Generator_loss:3.4475
# L1_loss:0.1601
# Discriminator_loss:0.1678
#
# EPOCH[48] - STEP[100]
# Generator_loss:3.3637
# L1_loss:0.1385
# Discriminator_loss:0.2081
#
# EPOCH[48] - STEP[200]
# Generator_loss:5.3043
# L1_loss:0.1206
# Discriminator_loss:0.7439
#
# EPOCH[49] - STEP[100]
# Generator_loss:3.5462
# L1_loss:0.1431
# Discriminator_loss:0.2434
#
# EPOCH[49] - STEP[200]
# Generator_loss:4.8869
# L1_loss:0.1126
# Discriminator_loss:0.2424
#
# EPOCH[50] - STEP[100]
# Generator_loss:0.9679
# L1_loss:0.1524
# Discriminator_loss:1.0653
#
# EPOCH[50] - STEP[200]
# Generator_loss:4.0335
# L1_loss:0.1578
# Discriminator_loss:0.0816

# %%
## Test

test_ind = 1

test_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/City/cityscapes/val/'

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# # 회고
#
# - 어려웠던 점, 해결방안
#
# GradientTape(persistent = True), opt.apply_gradients(), tf.constant, tf.pad("CONSTANT"), image.random_flip_left_right, tf.random.uniform() 등의 여러 메서드를 이해하는 데 시간이 좀 걸렸음
#
# - 결과 분석
#
# flip, random_crop등을 통해서 여러 augmentation을 적용하였고, U-Net model 구현을 완료하여 train_step(epoch =30)으로 안정적으로 진행되었음을 확인하였다.

# %% [markdown]
# <img width="518" alt="image" src="https://user-images.githubusercontent.com/78291267/158395173-30a1a2fd-e9dd-451d-82f6-82f0a513a662.png">
